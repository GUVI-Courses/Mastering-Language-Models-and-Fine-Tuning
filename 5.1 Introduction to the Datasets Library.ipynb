# %%
# !pip install datasets
import datasets

#https://huggingface.co/datasets/owaiskha9654/PubMed_MultiLabel_Text_Classification_Dataset_MeSH

# Load a dataset from the hub
dataset = datasets.load_dataset("owaiskha9654/PubMed_MultiLabel_Text_Classification_Dataset_MeSH")


# Access the 'train' split of the dataset
train_dataset = dataset['train']

# Split the train dataset into training and testing sets
train_dataset, test_dataset = train_dataset.train_test_split(test_size=0.2)

dataset
# Out:
# ...
# DatasetDict({
#     train: Dataset({
#         features: ['Title', 'abstractText', 'meshMajor', 'pmid', 'meshid', 'meshroot', 'A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'L', 'M', 'N', 'Z'],
#         num_rows: 50000
#     })
# })
